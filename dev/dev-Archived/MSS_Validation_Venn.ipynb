# %%
import sys
sys.path.append('../')
from mss import visreader as mvis
from mss import mssmain as msm
from mss import expire_alignment
import pandas as pd
import numpy as np

from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt

import seaborn as sns
import peakutils
import scipy
from scipy.integrate import simps
import itertools

# %%
df_mss = pd.read_csv('D:/UW/mssvalidation/20201119_ENTACT_validation_data/Venn/505_minscan5.csv')
df_msd = pd.read_excel('D:/UW/mssvalidation/20201119_ENTACT_validation_data/Venn/msdial_ENTACT_505.xlsx')
df_xcms = pd.read_excel('D:/UW/mssvalidation/20201119_ENTACT_validation_data/Venn/XCMS-Report-SingleClass.xlsx')

# %%
df_test1 = pd.read_csv('D:/UW/mssvalidation/20201119_ENTACT_validation_data/Venn/test1.csv')
df_test2 = pd.read_csv('D:/UW/mssvalidation/20201119_ENTACT_validation_data/Venn/test2.csv')

# %%
for i in range(5):
    for j in range (5):
        if i<j:
            print(i)

# %%
from tqdm import tqdm

# %%
mz_error = 0.015
rt_error = 0.5
df_ref = df_mss.copy()
df_align = df_msd.copy()
df_align2 = df_xcms.copy()
df_result = df_mss.copy()
df_result['mss'] = np.NaN
df_result['msd'] = np.NaN

for i in df_align.itertuples():
    for j in df_ref.itertuples():
        if (abs(i[2] - j[2]) <= rt_error) &  (abs(i[1] - j[1]) <= mz_error):
            df_result.at[i[0],'mss'] = 1

# %%
df_sum = pd.read_csv('D:/UW/mssvalidation/20201119_ENTACT_validation_data/Venn/msd_xcms_align.csv')

# %%
df = [df_mss,df_msd,df_xcms]

# %%
df = pd.read_csv('D:/UW/mssvalidation/20201119_ENTACT_validation_data/Venn/alignment.csv')

# %%
sum((df['msd-11']>0)&(df['xcms-1']>0)&(df['mss-1']>0))
# Out:
# 9587

# %%
align.mss_align(df,'D:/UW/mssvalidation/20201119_ENTACT_validation_data/Venn/alignment.csv',['mss-111111','msd-1111111','xcms-111111'],0.5, 0.015)
# Out:
# Process completed!
# Alignment beginning..
#   0%|          | 0/65258 [00:00<?, ?it/s]
#
#
#
#
#
#
#   0%|          | 38/65258 [00:00<02:56, 369.78it/s]
#
#
#
#
#
#
#   0%|          | 79/65258 [00:00<02:51, 380.22it/s]
#
#
#
#
#
#
#   0%|          | 117/65258 [00:00<02:53, 374.88it/s]
#
#
#
#
#
#
#   0%|          | 153/65258 [00:00<02:56, 368.29it/s]
#
#
#
#
#
#
#   0%|          | 190/65258 [00:00<02:56, 368.04it/s]
#
#
#
#
#
#
#   0%|          | 224/65258 [00:00<03:02, 356.06it/s]
#
#
#
#
#
#
#   0%|          | 264/65258 [00:00<02:56, 367.43it/s]
#
#
#
#
#
#
#   0%|          | 301/65258 [00:00<02:57, 365.23it/s]
#
#
#
#
#
#
#   1%|          | 338/65258 [00:00<02:57, 365.85it/s]
#
#
#
#
#
#
#   1%|          | 374/65258 [00:01<03:08, 343.56it/s]
#
#
#
#
#
#
#   1%|          | 408/65258 [00:01<03:10, 340.70it/s]
#
#
#
#
#
#
#   1%|          | 443/65258 [00:01<03:09, 342.70it/s]
#
#
#
#
#
#
#   1%|          | 482/65258 [00:01<03:03, 352.05it/s]
#
#
#
#
#
#
# ...
